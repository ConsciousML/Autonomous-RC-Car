# %%
import tensorflow as tf
from keras import backend as K

config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.8
session = tf.Session(config=config)

K.set_session(session)
# Out:
# Using TensorFlow backend.

# %%
# Out:
# 160

# %%
from src.learning.build_models import *
from src.learning.processing.build_dataset_angle import *

# %tb
BATCH = 8
f_dataset = "a_dataset.npy"
f_labels = "a_labels.npy"
generator_ = gen_data(f_dataset, f_labels, BATCH)
validation = []
for i in range(40):
    validation.append(next(generator_))

model = RecurrentMobileNet()

model.fit_generator(generator_, 4470/BATCH, 10, shuffle=False, validation=validation)

model.save("output/mobileNet2.h5")
# Out:
#  LOl
# salut
# No traceback available to show.
# c' est moi
# Epoch 1/10
# 559/558 [==============================] - 29s - loss: 0.0496 - mean_squared_error: 0.0496
# Epoch 2/10
# 559/558 [==============================] - 29s - loss: 0.0355 - mean_squared_error: 0.0355
# Epoch 3/10
# 559/558 [==============================] - 29s - loss: 0.0331 - mean_squared_error: 0.0331
# Epoch 4/10
# 559/558 [==============================] - 29s - loss: 0.0307 - mean_squared_error: 0.0307
# Epoch 5/10
# 559/558 [==============================] - 29s - loss: 0.0293 - mean_squared_error: 0.0293
# Epoch 6/10
# 559/558 [==============================] - 29s - loss: 0.0283 - mean_squared_error: 0.0283
# Epoch 7/10
# 559/558 [==============================] - 29s - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 8/10
# 559/558 [==============================] - 29s - loss: 0.0275 - mean_squared_error: 0.0275
# Epoch 9/10
# ...

# %%
from src.learning.build_models import *
from src.learning.processing.build_dataset_angle import *

BATCH = 8
f_dataset = "a_dataset.npy"
f_labels = "a_labels.npy"

generator_ = gen_data(f_dataset, f_labels, BATCH)
validation = next(generator_)

model = RecurrentMobileNet()
print(model.summary())

model.fit_generator(generator_, 4470/BATCH, 10, shuffle=False, validation_data=validation)

model.save("output/mobileNet_Rec.h5")
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_8 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, 112, 112, 32)      0
# ...
